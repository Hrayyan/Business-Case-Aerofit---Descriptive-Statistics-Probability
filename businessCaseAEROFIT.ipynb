# %% [markdown]
# <a href="https://colab.research.google.com/github/Hrayyan/Business-Case-Aerofit---Descriptive-Statistics-Probability/blob/main/businessCaseAEROFIT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PROBLEM STATEMENT**
#
#
#
# *   The market research team at AeroFit wants to identify the characteristics of the target audience for each type of treadmill offered by the company, to provide a better recommendation of the treadmills to the new customers. The team decides to investigate whether there are differences across the product with respect to customer characteristics.

# %%
import numpy as np , pandas as pd , matplotlib.pyplot as plt , seaborn as sns

# %%
df=pd.read_csv("/content/aerofit.csv")
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %% [markdown]
# **1- CHECKING THE STRUCTURE AND CHARACTERISTICS OF THE DATASET**

# %%
df.shape
# Out:
# (180, 9)

# %%
df['Product'].unique()
# Out:
# array(['KP281', 'KP481', 'KP781'], dtype=object)

# %%
df['Product'].nunique()
# Out:
# 3

# %%
df['Product'].value_counts()
# Out:
# KP281    80
# KP481    60
# KP781    40
# Name: Product, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
df.describe(include="all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      KP281         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %%
df.isnull().any()
# Out:
# Product          False
# Age              False
# Gender           False
# Education        False
# MaritalStatus    False
# Usage            False
# Fitness          False
# Income           False
# Miles            False
# dtype: bool

# %% [markdown]
#        ** INSIGHTS FROM HERE**
#        (i)- There isint any missing values in the dataset.
#        (ii)-There are only 3 products in the dataset, among which KP281
#             is the most frequent product.
#        (iii)-Minimum & Maximum age of the person is 18 & 50, with a
#              mean age of 28.79 and 75% of persons have age less than or equal to 33.
#        (IV)-Most of the people are having 16 years of education i.e.,
#            75% of persons are educated with <= 16 years.
#        (V)-Out of 180 peoples, 104 are Male and rest are the females.
#        (VI)-it can be noticed that Standard deviation for Income &
#             Miles is very high. it might be possible that there are outliers present in it.
#
#         **  RECOMMENDATIONS**
#         (I)- As of now Our Ideal Product is KP281 and Ideal customers
#              are males mostly aged upto 33 yrs with an education of upto 16 yrs

# %% [markdown]
# **VISUAL ANALYSIS**

# %% [markdown]
# Using Univariate Plots - Here we will understand the distribution of data for the quantitative attributes i.e those having a data type of int64

# %%
df['Education'].value_counts()
# Out:
# 16    85
# 14    55
# 18    23
# 15     5
# 13     5
# 12     3
# 21     3
# 20     1
# Name: Education, dtype: int64

# %%
df['Fitness'].value_counts()
# Out:
# 3    97
# 5    31
# 2    26
# 4    24
# 1     2
# Name: Fitness, dtype: int64

# %%
df['Usage'].value_counts()
# Out:
# 3    69
# 4    52
# 2    33
# 5    17
# 6     7
# 7     2
# Name: Usage, dtype: int64

# %%
df['Income'].value_counts()
# Out:
# 45480    14
# 52302     9
# 46617     8
# 54576     8
# 53439     8
#          ..
# 65220     1
# 55713     1
# 68220     1
# 30699     1
# 95508     1
# Name: Income, Length: 62, dtype: int64

# %%
# df['Miles'].value_counts(), # df['Age'].value_counts() # Have large outputs skipped because of bad asthetical appearence

# %%
fig, axis = plt.subplots(nrows=2, ncols=3, figsize=(8, 4))
fig.subplots_adjust(top=1.5)

sns.histplot(data=df, x="Age", kde=True, ax=axis[0,0])
sns.histplot(data=df, x="Education", kde=True, ax=axis[0,1])
sns.histplot(data=df, x="Usage", kde=True, ax=axis[0,2])
sns.histplot(data=df, x="Fitness", kde=True, ax=axis[1,0])
sns.histplot(data=df, x="Income", kde=True, ax=axis[1,1])
sns.histplot(data=df, x="Miles", kde=True, ax=axis[1,2])
plt.show()

# %%
fig, axis = plt.subplots(nrows=2, ncols=3, figsize=(8, 4))
fig.subplots_adjust(top=1.2)
sns.boxplot(data=df, x="Age", orient='h', ax=axis[0,0])
sns.boxplot(data=df, x="Education", orient='h', ax=axis[0,1])
sns.boxplot(data=df, x="Usage", orient='h', ax=axis[0,2])
sns.boxplot(data=df, x="Fitness", orient='h', ax=axis[1,0])
sns.boxplot(data=df, x="Income", orient='h', ax=axis[1,1])
sns.boxplot(data=df, x="Miles", orient='h', ax=axis[1,2])
plt.show()

# %% [markdown]
# INSIGHTS FROM HERE:
#
# (I)- so from the above two plots it can be noticed that data for Age,Income and miles is somewhat normally distributed
#
# (II)- and from the boxplot we can examin the outliers present in the data as per the std. dev. there are lot of outliers present in income and miles columns

# %% [markdown]
# Now we will understand the distribution of data for the qualitative attributes i.e those having a data type of object

# %%
df['Product'].value_counts()
# Out:
# KP281    80
# KP481    60
# KP781    40
# Name: Product, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Male      104
# Female     76
# Name: Gender, dtype: int64

# %%
df['MaritalStatus'].value_counts()
# Out:
# Partnered    107
# Single        73
# Name: MaritalStatus, dtype: int64

# %%
fig , axs = plt.subplots(nrows=1, ncols=3, figsize=(8,4))
sns.countplot(data=df, x='Product', ax=axs[0])
sns.countplot(data=df, x='Gender', ax=axs[1])
sns.countplot(data=df, x='MaritalStatus', ax=axs[2])

axs[0].set_title("Product - counts", pad=10, fontsize=14)
axs[1].set_title("Gender - counts", pad=10, fontsize=14)
axs[2].set_title("MaritalStatus - counts", pad=10, fontsize=14)
plt.show()

# %% [markdown]
# calculating the percentage of a perticular value of a qualitative attributes

# %%
df1 = df[['Product', 'Gender', 'MaritalStatus']].melt()
df1.groupby(['variable', 'value'])[['value']].count() / len(df)    # count of that perticular value/ total length
# Out:
#                             value
# variable      value
# Gender        Female     0.422222
#               Male       0.577778
# MaritalStatus Partnered  0.594444
#               Single     0.405556
# Product       KP281      0.444444
#               KP481      0.333333
#               KP781      0.222222

# %%
(df['Product'].value_counts(normalize=True))*100   # Alternate Way
# Out:
# KP281    44.444444
# KP481    33.333333
# KP781    22.222222
# Name: Product, dtype: float64

# %%
(df['MaritalStatus'].value_counts(normalize=True))*100
# Out:
# Partnered    59.444444
# Single       40.555556
# Name: MaritalStatus, dtype: float64

# %%
(df['Gender'].value_counts(normalize=True))*100
# Out:
# Male      57.777778
# Female    42.222222
# Name: Gender, dtype: float64

# %% [markdown]
# INSIGHTS FROM HERE:
#
# (I)-KP281 is the most frequently purchased product
#
# (II)- more males and partnered persons are using the products

# %% [markdown]
# **BIVARIATE ANALYSIS**

# %% [markdown]
# lets check what variation do various attributes have with the product purchased using countplot and boxplot accordingly for different attributes

# %%
sns.set_style(style='whitegrid')
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(8, 4))
sns.countplot(data=df, x='Product', hue='Gender', edgecolor="0.15",palette='Set2', ax=axs[0])
sns.countplot(data=df, x='Product', hue='MaritalStatus', edgecolor="0.15", palette='Set3', ax=axs[1])
axs[0].set_title("Product vs Gender", pad=10, fontsize=14)
axs[1].set_title("Product vs MaritalStatus", pad=10, fontsize=14)
plt.show()

# %%
attributes = ['Age', 'Education', 'Usage', 'Fitness', 'Income','Miles']
sns.set_style("white")
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(12, 8))
fig.subplots_adjust(top=1.2)
count=0
for i in range(2):
  for j in range(3):
    sns.boxplot(data=df, x='Product', y=attributes[count], ax=axs[i,j], palette='Set3')
    axs[i,j].set_title(f"Product vs {attributes[count]}",pad=8, fontsize=13)
    count += 1

# %%
sns.set_style(style='whitegrid')     #LAYMAN APPROACH
fig, axis = plt.subplots(nrows=2, ncols=3, figsize=(12, 8))
fig.subplots_adjust(top=1.2)
sns.boxplot(data=df, x='Product', y='Age', palette='Set3', ax=axis[0,0])
sns.boxplot(data=df, x='Product', y='Education', palette='Set3', ax=axis[0,1])
sns.boxplot(data=df, x='Product', y='Usage', palette='Set3', ax=axis[0,2])
sns.boxplot(data=df, x='Product', y='Fitness', palette='Set3', ax=axis[1,0])
sns.boxplot(data=df, x='Product', y='Income', palette='Set3', ax=axis[1,1])
sns.boxplot(data=df, x='Product', y='Miles', palette='Set3', ax=axis[1,2])
axis[0,0].set_title("Product vs Age", pad=10, fontsize=14)
axis[0,1].set_title("Product vs Education", pad=10, fontsize=14)
axis[0,2].set_title("Product vs Usage", pad=10, fontsize=14)
axis[1,0].set_title("Product vs Fitness", pad=10, fontsize=14)
axis[1,1].set_title("Product vs Income", pad=10, fontsize=14)
axis[1,2].set_title("Product vs Miles", pad=10, fontsize=14)
plt.show()

# %% [markdown]
# **INSIGHTS FROM HERE:**
#
# PRODUCT VS GENDER:
#
#  (I)-It can be observed that equal number of males and females are willing to purchase KP281 AND KP481 product
#
#  (II)- Furthermore there is a drastic decrease in females showing willingness to buy the premium KP781 product but males in that also are showing willingness to buy

# %% [markdown]
# PRODUCT VS MARITAL STATUS:
#
# (I)- Partnered peoples are more health councious having a good buying capacity then the single ones

# %% [markdown]
# PRODUCT VS AGE:
#
# (I)-It can be noticed that customers purchasing KP281 AND KP481 are having almost same Age band width with exactly same median
#
# (II)- KP781 is more likely to be purchased by peoples in age group of 25-30

# %% [markdown]
# PRODUCT VS EDUCATION:
#
# (I)- It is clearly visible that customers with education of more then 16 yrs are more willing to buy the premium KP781 product while
#
# (II)- The customers with education of less then 16 have the equal chances of buying KP281 AND KP481 Product

# %% [markdown]
# PRODUCT VS USAGE:
#
# (I)- Customers willing to use the tredmill for more then 4 times a week are tend to buy the KP781 product while the other two have no such effect of usage on buying potential

# %% [markdown]
# PRODUCT VS FITNESS:
#
# (I)- Very clear results fitness(>=3) is directly proportnal to buying tendency of premium KP781 product

# %% [markdown]
# PRODUCT VS INCOME:
#
# (I)-If the income of the customer is >=60000 higher chances are there that he will buy a KP781

# %% [markdown]
# PRODUCT VS MILES:
#
# (I)- If the distance a customer is covering on a tredmill is more then 120 miles  a week higher chances are there that he will buy a KP781

# %% [markdown]
# **MULTIVARIATE ANALYSIS**

# %%
attributes = ['Age', 'Education', 'Usage', 'Fitness', 'Income', 'Miles']
sns.set_style("white")
fig, axs = plt.subplots(nrows=3, ncols=2, figsize=(12, 8))
fig.subplots_adjust(top=1)
count = 0
for i in range(3):
  for j in range(2):
    sns.boxplot(data=df, x='Gender', y=attributes[count], hue='Product', ax=axs[i,j], palette='Set3')
    axs[i,j].set_title(f"Product vs {attributes[count]}", pad=8, fontsize=13)
    count += 1

# %%
sns.set_style(style='whitegrid')     #LAYMAN APPROACH
fig, axis = plt.subplots(nrows=3, ncols=2, figsize=(12, 8))
fig.subplots_adjust(top=1)
sns.boxplot(data=df, x='Gender', y='Age', hue='Product', palette='Set3', ax=axis[0,0])
sns.boxplot(data=df, x='Gender', y='Education', hue='Product', palette='Set3', ax=axis[0,1])
sns.boxplot(data=df, x='Gender', y='Usage', hue='Product', palette='Set3', ax=axis[1,0])
sns.boxplot(data=df, x='Gender', y='Fitness', hue='Product', palette='Set3', ax=axis[1,1])
sns.boxplot(data=df, x='Gender', y='Income', hue='Product', palette='Set3', ax=axis[2,0])
sns.boxplot(data=df, x='Gender', y='Miles', hue='Product', palette='Set3', ax=axis[2,1])
axis[0,0].set_title("Product vs Age", pad=10, fontsize=14)
axis[0,1].set_title("Product vs Education", pad=10, fontsize=14)
axis[1,0].set_title("Product vs Usage", pad=10, fontsize=14)
axis[1,1].set_title("Product vs Fitness", pad=10, fontsize=14)
axis[2,0].set_title("Product vs Income", pad=10, fontsize=14)
axis[2,1].set_title("Product vs Miles", pad=10, fontsize=14)
plt.show()

# %% [markdown]
# INSIGHTS FROM HERE:
#
# We have done an analysis here for both male and females with respect to all the quantitative attributes the observation is near about same for both male and females but in case of usage we see that females who use the tredmill 3-4 times a week are willing to buy KP481

# %% [markdown]
# **Computing Marginal & Conditional Probabilities:**

# %% [markdown]
# Marginal Probability

# %%
(df['Product'].value_counts(normalize=True))*100
# Out:
# KP281    44.444444
# KP481    33.333333
# KP781    22.222222
# Name: Product, dtype: float64

# %% [markdown]
# Conditional Probability

# %%
def p_prod_given_gender(gender, print_marginal=False):
  if gender is not "Female" and gender is not "Male":
    return "Invalid gender value."
  df1 = pd.crosstab(index=df['Gender'], columns=[df['Product']])
  p_781 = df1['KP781'][gender] / df1.loc[gender].sum()
  p_481 = df1['KP481'][gender] / df1.loc[gender].sum()
  p_281 = df1['KP281'][gender] / df1.loc[gender].sum()
  if print_marginal:
    print(f"P(Male): {df1.loc['Male'].sum()/len(df):.2f}")
    print(f"P(Female): {df1.loc['Female'].sum()/len(df):.2f}\n")
  print(f"P(KP781/{gender}): {p_781:.2f}")
  print(f"P(KP481/{gender}): {p_481:.2f}")
  print(f"P(KP281/{gender}): {p_281:.2f}\n")
p_prod_given_gender('Male', True)
p_prod_given_gender('Female')
# Out:
# P(Male): 0.58
# P(Female): 0.42
#
# P(KP781/Male): 0.32
# P(KP481/Male): 0.30
# P(KP281/Male): 0.38
#
# P(KP781/Female): 0.09
# P(KP481/Female): 0.38
# P(KP281/Female): 0.53
# <>:2: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:2: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:2: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:2: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <ipython-input-29-a583626effe2>:2: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if gender is not "Female" and gender is not "Male":
# <ipython-input-29-a583626effe2>:2: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if gender is not "Female" and gender is not "Male":
